# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data-clensing.csv')
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#          Date TweetNo             User  \
# 0  06/02/2022       1      Filimon1987
# 1  06/02/2022       2     amir_shazrin
# 2  06/02/2022       3          umit587
# 3  06/02/2022       4  realwhalehacker
# 4  06/02/2022       5      hasanKylp33
#
#                                                Tweet
# 0  RT @hardbitspace: BitTorrent 10000.\nRetweet t...
# 1  RT @ElonPunkYC: Floor went from 5 ETH to 8.6 E...
# 2  RT @fzthsyn: Tercihini hangi kedilerden yana  ...
# 3  "The FTX ad with Brady had some charm, it's cu...
# 4  RT @fzthsyn: Tercihini hangi kedilerden yana  ...

# %%
tweet=df['Tweet']

# %%
tweet
# Out:
# 0         RT @hardbitspace: BitTorrent 10000.\nRetweet t...
# 1         RT @ElonPunkYC: Floor went from 5 ETH to 8.6 E...
# 2         RT @fzthsyn: Tercihini hangi kedilerden yana  ...
# 3         "The FTX ad with Brady had some charm, it's cu...
# 4         RT @fzthsyn: Tercihini hangi kedilerden yana  ...
#                                 ...
# 415337    RT @Decent_az001: #MarvinInu is talked about e...
# 415338    RT @austinahilton: LIVE - Q &amp; A! SHIBA INU...
# 415339    RT @austinahilton: WHY SHIBA INU IS DOWN - FIN...
# 415340    RT @austinahilton: SHIBA INU - "IT'S ALIVE!" h...
# 415341    🛑BITCOIN BULLISH/BEARISH?SHIBA INU COIN PRICE ...
# Name: Tweet, Length: 415342, dtype: object

# %%
from requests import Request, Session
import json
import pprint




url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest'
parameters = {
   'symbol': 'DOGE,SHIB,ELON,SAMO,HOGE,MONA',
   'convert':'USD'
}

headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY':'21cc874e-fec2-4676-91e3-4b20730009d0'
}

session = Session()
session.headers.update(headers)

response = session.get(url, params=parameters)
pprint.pprint(json.loads(response.text))
# Out:
# {'data': {'DOGE': {'circulating_supply': 132670764299.89409,
#                    'cmc_rank': 10,
#                    'date_added': '2013-12-15T00:00:00.000Z',
#                    'id': 74,
#                    'is_active': 1,
#                    'is_fiat': 0,
#                    'last_updated': '2022-05-13T13:40:00.000Z',
#                    'max_supply': None,
#                    'name': 'Dogecoin',
#                    'num_market_pairs': 473,
#                    'platform': None,
#                    'quote': {'USD': {'fully_diluted_market_cap': 12122801488.67,
#                                      'last_updated': '2022-05-13T13:40:00.000Z',
#                                      'market_cap': 12122801488.669937,
#                                      'market_cap_dominance': 0.924,
#                                      'percent_change_1h': -1.55598975,
#                                      'percent_change_24h': 18.39082352,
#                                      'percent_change_30d': -34.0404894,
#                                      'percent_change_60d': -19.69694778,
#                                      'percent_change_7d': -27.0405995,
#                                      'percent_change_90d': -35.86307166,
#                                      'price': 0.0913750783953207,
#                                      'volume_24h': 1952325573.1364708,
#                                      'volume_change_24h': -33.3661}},
#                    'self_reported_circulating_supply': None,
#                    'self_reported_market_cap': None,
#                    'slug': 'dogecoin',
#                    'symbol': 'DOGE',
#                    'tags': ['mineable',
#                             'pow',
#                             'scrypt',
#                             'medium-of-exchange',
#                             'memes',
#                             'payments',
#                             'doggone-doggerel',
#                             'bnb-chain'],
#                    'total_supply': 132670764299.89409},
#           'ELON': {'circulating_supply': 552305422941315.94,
#                    'cmc_rank': 115,
#                    'date_added': '2021-04-23T00:00:00.000Z',
#                    'id': 9436,
#                    'is_active': 1,
#                    'is_fiat': 0,
#                    'last_updated': '2022-05-13T13:39:00.000Z',
#                    'max_supply': 1000000000000000,
#                    'name': 'Dogelon Mars',
#                    'num_market_pairs': 45,
#                    'platform': {'id': 1,
#                                 'name': 'Ethereum',
#                                 'slug': 'dogelon',
#                                 'symbol': 'ELON',
#                                 'token_address': '0x761d38e5ddf6ccf6cf7c55759d5210750b5d60f3'},
#                    'quote': {'USD': {'fully_diluted_market_cap': 573135722.98,
#                                      'last_updated': '2022-05-13T13:39:00.000Z',
#                                      'market_cap': 316545967.88569,
#                                      'market_cap_dominance': 0.0241,
#                                      'percent_change_1h': -1.56699978,
#                                      'percent_change_24h': 34.15282225,
#                                      'percent_change_30d': -28.14398533,
#                                      'percent_change_60d': -14.83740477,
#                                      'percent_change_7d': -32.3657453,
#                                      'percent_change_90d': -38.8245806,
#                                      'price': 5.731357229844255e-07,
#                                      'volume_24h': 50040378.19898568,
#                                      'volume_change_24h': -0.9048}},
#                    'self_reported_circulating_supply': None,
#                    'self_reported_market_cap': None,
#                    'slug': 'dogelon',
#                    'symbol': 'ELON',
#                    'tags': ['memes',
#                             'payments',
#                             'polygon-ecosystem',
#                             'doggone-doggerel'],
#                    'total_supply': 1000000000000000},
#           'HOGE': {'circulating_supply': 402276464812,
#                    'cmc_rank': 773,
#                    'date_added': '2021-02-12T00:00:00.000Z',
#                    'id': 8438,
#                    'is_active': 1,
#                    'is_fiat': 0,
#                    'last_updated': '2022-05-13T13:40:00.000Z',
#                    'max_supply': 1000000000000,
#                    'name': 'Hoge Finance',
#                    'num_market_pairs': 17,
#                    'platform': {'id': 1,
#                                 'name': 'Ethereum',
#                                 'slug': 'hoge-finance',
#                                 'symbol': 'HOGE',
#                                 'token_address': '0xfad45e47083e4607302aa43c65fb3106f1cd7607'},
#                    'quote': {'USD': {'fully_diluted_market_cap': 26442284.89,
#                                      'last_updated': '2022-05-13T13:40:00.000Z',
#                                      'market_cap': 10637108.886563234,
#                                      'market_cap_dominance': 0,
#                                      'percent_change_1h': -0.77281558,
#                                      'percent_change_24h': 16.56784122,
#                                      'percent_change_30d': -50.33127245,
#                                      'percent_change_60d': -58.42318924,
#                                      'percent_change_7d': -32.89853465,
#                                      'percent_change_90d': -72.72292455,
#                                      'price': 2.6442284888663284e-05,
#                                      'volume_24h': 92971.49079881,
#                                      'volume_change_24h': -4.8154}},
#                    'self_reported_circulating_supply': None,
#                    'self_reported_market_cap': None,
#                    'slug': 'hoge-finance',
#                    'symbol': 'HOGE',
#                    'tags': ['gaming', 'memes', 'bnb-chain'],
#                    'total_supply': 402276464812},
#           'MONA': {'circulating_supply': 65729674.871168,
#                    'cmc_rank': 423,
#                    'date_added': '2014-03-20T00:00:00.000Z',
#                    'id': 213,
#                    'is_active': 1,
#                    'is_fiat': 0,
#                    'last_updated': '2022-05-13T13:40:00.000Z',
#                    'max_supply': 105120000,
#                    'name': 'MonaCoin',
#                    'num_market_pairs': 22,
#                    'platform': None,
#                    'quote': {'USD': {'fully_diluted_market_cap': 73961565.91,
#                                      'last_updated': '2022-05-13T13:40:00.000Z',
#                                      'market_cap': 46246857.69102761,
#                                      'market_cap_dominance': 0,
#                                      'percent_change_1h': 0.5857755,
#                                      'percent_change_24h': 19.4565745,
#                                      'percent_change_30d': -22.28091454,
#                                      'percent_change_60d': -24.84427149,
#                                      'percent_change_7d': -8.86248377,
#                                      'percent_change_90d': -32.53446188,
#                                      'price': 0.7035917609766478,
#                                      'volume_24h': 463216.72380263,
#                                      'volume_change_24h': -20.6398}},
#                    'self_reported_circulating_supply': None,
#                    'self_reported_market_cap': None,
#                    'slug': 'monacoin',
#                    'symbol': 'MONA',
#                    'tags': ['mineable',
#                             'pow',
#                             'lyra2rev2',
#                             'medium-of-exchange',
#                             'memes',
#                             'payments'],
#                    'total_supply': 65729674.871168},
#           'SAMO': {'circulating_supply': 3328268031,
#                    'cmc_rank': 578,
#                    'date_added': '2021-05-12T00:00:00.000Z',
#                    'id': 9721,
#                    'is_active': 1,
#                    'is_fiat': 0,
#                    'last_updated': '2022-05-13T13:39:00.000Z',
#                    'max_supply': 9238477429,
#                    'name': 'Samoyedcoin',
#                    'num_market_pairs': 22,
#                    'platform': {'id': 16,
#                                 'name': 'Solana',
#                                 'slug': 'samoyedcoin',
#                                 'symbol': 'SAMO',
#                                 'token_address': '7xKXtg2CW87d97TXJSDpbD5jBkheTqA83TZRuJosgAsU'},
#                    'quote': {'USD': {'fully_diluted_market_cap': 67178440.58,
#                                      'last_updated': '2022-05-13T13:39:00.000Z',
#                                      'market_cap': 24201807.91395127,
#                                      'market_cap_dominance': 0,
#                                      'percent_change_1h': 2.11519799,
#                                      'percent_change_24h': 30.30459984,
#                                      'percent_change_30d': -59.99461714,
#                                      'percent_change_60d': -57.88083179,
#                                      'percent_change_7d': -42.35518389,
#                                      'percent_change_90d': -71.2397094,
#                                      'price': 0.00727159221809419,
#                                      'volume_24h': 4546393.60095886,
#                                      'volume_change_24h': -28.6985}},
#                    'self_reported_circulating_supply': None,
#                    'self_reported_market_cap': None,
#                    'slug': 'samoyedcoin',
#                    'symbol': 'SAMO',
#                    'tags': ['memes', 'solana-ecosystem', 'doggone-doggerel'],
#                    'total_supply': 7746913929},
#           'SHIB': {'circulating_supply': 549063278876301.94,
#                    'cmc_rank': 14,
#                    'date_added': '2020-08-01T00:00:00.000Z',
#                    'id': 5994,
#                    'is_active': 1,
#                    'is_fiat': 0,
#                    'last_updated': '2022-05-13T13:39:00.000Z',
#                    'max_supply': None,
#                    'name': 'Shiba Inu',
#                    'num_market_pairs': 347,
#                    'platform': {'id': 1,
#                                 'name': 'Ethereum',
#                                 'slug': 'shiba-inu',
#                                 'symbol': 'SHIB',
#                                 'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#                    'quote': {'USD': {'fully_diluted_market_cap': 8068759805.51,
#                                      'last_updated': '2022-05-13T13:39:00.000Z',
#                                      'market_cap': 7512288547.979603,
#                                      'market_cap_dominance': 0.5726,
#                                      'percent_change_1h': -1.1206229,
#                                      'percent_change_24h': 30.60644982,
#                                      'percent_change_30d': -47.65689612,
#                                      'percent_change_60d': -37.05498274,
#                                      'percent_change_7d': -30.73257343,
#                                      'percent_change_90d': -52.17016243,
#                                      'price': 1.3682008680955772e-05,
#                                      'volume_24h': 1524095880.8291411,
#                                      'volume_change_24h': -7.4645}},
#                    'self_reported_circulating_supply': None,
#                    'self_reported_market_cap': None,
#                    'slug': 'shiba-inu',
#                    'symbol': 'SHIB',
#                    'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel'],
#                    'total_supply': 589735030408322.8}},
#  'status': {'credit_count': 1,
#             'elapsed': 30,
#             'error_code': 0,
#             'error_message': None,
#             'notice': None,
#             'timestamp': '2022-05-13T13:40:55.407Z'}}

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
 
example_sent = """This is a sample sentence,
                  showing off the stop words filtration."""
 
stop_words = set(stopwords.words('english'))
 
word_tokens = word_tokenize(example_sent)
 
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
 
filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
 
print(word_tokens)
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
df = pd.read_csv('Mona-date.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/446288636.py in <module>
# ----> 1 df = pd.read_csv('Mona-date.csv')
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# c:\Users\moham\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Mona-date.csv'
